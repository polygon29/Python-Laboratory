# %% [markdown]
# รหัส 6610110351 ชื่อ เสฎฐวุฒิ สุภักดี Sec 07 Asm Lab07

# %%
#ตรวจสอบข้อที่ทำ
STcode = int(input('Student Code: '))
scode = STcode%1000
print('scode = ', scode)
a = scode%4
print('a = scode%4 =', a)
asm = {1:'A1', 2:'A2', 3:'A3', 0:'A4'}
print('คุณได้ทำข้อ', asm[a])
# Out:
# Student Code: 6610110351
# scode =  351
# a = scode%4 = 3
# คุณได้ทำข้อ A3

# %%
#A3. Triangle โปรแกรมรับค่าจำนวนจริงบวก a และ b ซึ่งเป็นด้านประกอบมุมฉากของรูปสามเหลี่ยมมุมฉาก จงคำนวณหาค่ามุม theta โดยแสดงเป็นค่าเรเดียนและมุมองศา และคำนวณหาความยาวด้าน c
print('Right triangle a, b, c')
a, b = [float(x) for x in input('Input a, b : ').split()]
import math
a = abs(a)
b = abs(b)
radian = math.atan(a/b)
degree = radian/math.pi*180
c = math.sqrt(a*a+b*b)
print(F'theta = {radian:.5f} radian')
print(F'theta = {degree:.3f} degrees')
print(F'c = {c:.5f}')
# Out:
# Right triangle a, b, c
# Input a, b : 10 10
# theta = 0.78540 radian
# theta = 45.000 degrees
# c = 14.14214
