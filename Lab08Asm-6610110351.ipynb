# %% [markdown]
# รหัส 6610110351 ชื่อ เสฎฐวุฒิ สุภักดี Sec 07 Asm Lab08

# %%
#ตรวจสอบข้อที่ทำ
STcode = int(input('Student Code: '))
scode = STcode%1000
print('scode = ', scode)
a = scode%4
print('a = scode%4 =', a)
asm = {1:'A2', 2:'A3', 3:'A4', 0:'A1'}
print('คุณได้ทำข้อ', asm[a])
# Out:
# Student Code: 6610110351
# scode =  351
# a = scode%4 = 3
# คุณได้ทำข้อ A4

# %%
#A4. จงเขียนฟังก์ชัน func(lst, lstEven, lstOdd) สำหรับเรียงค่าตัวเลขในลิสต์ lst แล้วเลือกเก็บข้อมูลที่เป็นเลขคู่ลงในลิสต์ lstEven และเก็บเลขคี่ลงในลิสต์ lstOdd

def func(lst, lstEven, lstOdd) :
  A = lst.sort()
  for i in lst :
    if i%2 == 0 :
      lstEven.append(i)
    else :
      lstOdd.append(i)
  return

def main() :
  A = [int(x) for x in input().split()]
  print('A =' , A)
  B = []
  C = []
  func(A, B, C)
  print('Sorted A =' , A)
  print('Even numbers =' , B)
  print('Odd numbers =' , C)

main()
print()
# Out:
# 14 2 569 -74 -51
# A = [14, 2, 569, -74, -51]
# Sorted A = [-74, -51, 2, 14, 569]
# Even numbers = [-74, 2, 14]
# Odd numbers = [-51, 569]
